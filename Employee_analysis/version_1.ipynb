# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None)

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')
submit = pd.read_csv('sample_submission.csv')

# %%
df_train.head()
# Out:
#   Employee_ID Gender   Age  Education_Level Relationship_Status     Hometown  \
# 0   EID_23371      F  42.0                4             Married     Franklin
# 1   EID_18000      M  24.0                3              Single  Springfield
# 2    EID_3891      F  58.0                3             Married      Clinton
# 3   EID_17492      F  26.0                3              Single      Lebanon
# 4   EID_22534      F  31.0                1             Married  Springfield
#
#                         Unit Decision_skill_possess  Time_of_service  \
# 0                         IT             Conceptual              4.0
# 1                  Logistics             Analytical              5.0
# 2                    Quality             Conceptual             27.0
# 3  Human Resource Management             Behavioral              4.0
# 4                  Logistics             Conceptual              5.0
#
#    Time_since_promotion  growth_rate  Travel_Rate  Post_Level  Pay_Scale  \
# 0                     4           33            1           1        7.0
# 1                     4           36            0           3        6.0
# 2                     3           51            0           2        8.0
# 3                     3           56            1           3        8.0
# 4                     4           62            1           3        2.0
#
#   Compensation_and_Benefits  Work_Life_balance  VAR1    VAR2    VAR3  \
# 0                     type2                3.0     4  0.7516  1.8688
# 1                     type2                4.0     3 -0.9612 -0.4537
# 2                     type2                1.0     4 -0.9612 -0.4537
# 3                     type2                1.0     3 -1.8176 -0.4537
# 4                     type3                3.0     1  0.7516 -0.4537
#
#        VAR4  VAR5  VAR6  VAR7  Attrition_rate
# 0  2.000000     4     5     3          0.1841
# 1  2.000000     3     5     3          0.0670
# 2  3.000000     3     8     3          0.0851
# 3  1.891078     3     7     3          0.0668
# 4  2.000000     2     8     2          0.1827

# %%
a = df_train.Unit.to_numpy()
unique, counts = np.unique(a, return_counts = True)
plt.figure(figsize = (14,6))

plt.bar(unique, counts)
plt.title('Unit distribution', size = 20)
plt.xlabel('Sector', size = 15)
plt.xticks(rotation = 45)
plt.ylabel('Counts', size = 15)
# Out:
# Text(0, 0.5, 'Counts')

# %%
a = df_train.Age.to_numpy()
unique, counts = np.unique(a, return_counts = True)
plt.figure(figsize = (14,6))

plt.bar(unique, counts)
plt.title('Age distribution', size = 20)
plt.xlabel('Age', size = 15)

plt.ylabel('Counts', size = 15)
# Out:
# Text(0, 0.5, 'Counts')

# %%
a = df_train.Education_Level.to_numpy()
unique, counts = np.unique(a, return_counts = True)

fig, ax = plt.subplots()
plt.bar(unique, counts)
plt.title('Education Level distribution', size = 15)
plt.xlabel('Levels', size = 12)
plt.ylabel('Counts', size = 12)

for i, v in enumerate(counts):
    ax.text(i+1-.25, 
              v/counts[i]+100, 
              counts[i], 
              fontsize=13)

# %%
a = df_train.Hometown.to_numpy()
unique, counts = np.unique(a, return_counts = True)

fig, ax = plt.subplots() 
plt.bar(unique, counts)
plt.title('Hometown distribution', size = 15)
plt.xlabel('Towns', size = 12)
plt.ylabel('Counts', size = 12)

for i, v in enumerate(counts):
    ax.text(i-.25, 
              v/counts[i]+100, 
              counts[i], 
              fontsize=15)

# %%
a = df_train.Decision_skill_possess.to_numpy()
unique, counts = np.unique(a, return_counts = True)

fig, ax = plt.subplots() 
plt.bar(unique, counts)
plt.title('Decision skill possess distribution', size = 15)
plt.xlabel('Skills', size = 12)
plt.ylabel('Counts', size = 12)

for i, v in enumerate(counts):
    ax.text(i-.25, 
              v/counts[i]+100, 
              counts[i], 
              fontsize=15)

# %%
a = df_train.Compensation_and_Benefits.to_numpy()
unique, counts = np.unique(a, return_counts = True)

fig, ax = plt.subplots() 
plt.bar(unique, counts)
plt.title('Compensation & Benefits distribution', size = 15)
plt.xlabel('Types', size = 12)
plt.ylabel('Counts', size = 12)

for i, v in enumerate(counts):
    ax.text(i-.25, 
              v/counts[i]+100, 
              counts[i], 
              fontsize=15)

# %%
df_train.isnull().sum()
# Out:
# Employee_ID                    0
# Gender                         0
# Age                          412
# Education_Level                0
# Relationship_Status            0
# Hometown                       0
# Unit                           0
# Decision_skill_possess         0
# Time_of_service              144
# Time_since_promotion           0
# growth_rate                    0
# Travel_Rate                    0
# Post_Level                     0
# Pay_Scale                      9
# Compensation_and_Benefits      0
# Work_Life_balance             11
# VAR1                           0
# VAR2                         577
# VAR3                           0
# VAR4                         656
# VAR5                           0
# VAR6                           0
# VAR7                           0
# Attrition_rate                 0
# dtype: int64

# %%
df_train.describe()
# Out:
#                Age  Education_Level  Time_of_service  Time_since_promotion  \
# count  6588.000000      7000.000000      6856.000000           7000.000000
# mean     39.622799         3.187857        13.385064              2.367143
# std      13.606920         1.065102        10.364188              1.149395
# min      19.000000         1.000000         0.000000              0.000000
# 25%      27.000000         3.000000         5.000000              1.000000
# 50%      37.000000         3.000000        10.000000              2.000000
# 75%      52.000000         4.000000        21.000000              3.000000
# max      65.000000         5.000000        43.000000              4.000000
#
#        growth_rate  Travel_Rate   Post_Level    Pay_Scale  Work_Life_balance  \
# count  7000.000000  7000.000000  7000.000000  6991.000000        6989.000000
# mean     47.064286     0.817857     2.798000     6.006294           2.387895
# std      15.761406     0.648205     1.163721     2.058435           1.122786
# min      20.000000     0.000000     1.000000     1.000000           1.000000
# 25%      33.000000     0.000000     2.000000     5.000000           1.000000
# 50%      47.000000     1.000000     3.000000     6.000000           2.000000
# 75%      61.000000     1.000000     3.000000     8.000000           3.000000
# max      74.000000     2.000000     5.000000    10.000000           5.000000
#
#               VAR1         VAR2         VAR3         VAR4         VAR5  \
# count  7000.000000  6423.000000  7000.000000  6344.000000  7000.000000
# mean      3.098571    -0.008126    -0.013606     1.891078     2.834143
# std       0.836377     0.989850     0.986933     0.529403     0.938945
# min       1.000000    -1.817600    -2.776200     1.000000     1.000000
# 25%       3.000000    -0.961200    -0.453700     2.000000     2.000000
# 50%       3.000000    -0.104800    -0.453700     2.000000     3.000000
# 75%       3.000000     0.751600     0.707500     2.000000     3.000000
# max       5.000000     1.608100     1.868800     3.000000     5.000000
#
#               VAR6         VAR7  Attrition_rate
# count  7000.000000  7000.000000     7000.000000
# mean      7.101286     3.257000        0.189376
# std       1.164262     0.925319        0.185753
# min       5.000000     1.000000        0.000000
# 25%       6.000000     3.000000        0.070400
# 50%       7.000000     3.000000        0.142650
# 75%       8.000000     4.000000        0.235000
# max       9.000000     5.000000        0.995900

# %%
df_test.describe()
# Out:
#                Age  Education_Level  Time_of_service  Time_since_promotion  \
# count  2839.000000      3000.000000      2948.000000           3000.000000
# mean     39.797816         3.226333        13.403664              2.405333
# std      13.501754         1.065904        10.189245              1.150426
# min      19.000000         1.000000         0.000000              0.000000
# 25%      27.000000         3.000000         5.000000              1.000000
# 50%      38.000000         3.000000        10.000000              2.000000
# 75%      52.000000         4.000000        21.000000              3.000000
# max      65.000000         5.000000        43.000000              4.000000
#
#        growth_rate  Travel_Rate   Post_Level    Pay_Scale  Work_Life_balance  \
# count  3000.000000  3000.000000  3000.000000  2997.000000        2995.000000
# mean     46.878000     0.827333     2.794667     6.060727           2.380968
# std      16.051947     0.642643     1.188125     2.096866           1.142826
# min      20.000000     0.000000     1.000000     1.000000           1.000000
# 25%      33.000000     0.000000     2.000000     5.000000           1.000000
# 50%      47.000000     1.000000     3.000000     6.000000           2.000000
# 75%      60.000000     1.000000     4.000000     8.000000           3.000000
# max      74.000000     2.000000     5.000000    10.000000           5.000000
#
#               VAR1         VAR2         VAR3         VAR4         VAR5  \
# count  3000.000000  2783.000000  3000.000000  2702.000000  3000.000000
# mean      3.067000     0.027530     0.012328     1.907476     2.836333
# std       0.821017     0.999799     0.999734     0.544526     0.940837
# min       1.000000    -1.817600    -2.776200     1.000000     1.000000
# 25%       3.000000    -0.961200    -0.453700     2.000000     2.000000
# 50%       3.000000    -0.104800    -0.453700     2.000000     3.000000
# 75%       3.000000     0.751600     0.707500     2.000000     3.000000
# max       5.000000     1.608100     1.868800     3.000000     5.000000
#
#               VAR6         VAR7
# count  3000.000000  3000.000000
# mean      7.130333     3.232333
# std       1.152876     0.903305
# min       5.000000     1.000000
# 25%       6.000000     3.000000
# 50%       7.000000     3.000000
# 75%       8.000000     4.000000
# max       9.000000     5.000000

# %%
df_train['VAR2'] = df_train['VAR2'].replace(np.NaN, df_train['VAR2'].mean())
df_train['VAR4'] = df_train['VAR4'].replace(np.NaN, df_train['VAR4'].mean())
df_train['Age'] = df_train['Age'].replace(np.NaN, df_train['Age'].mean())
df_train['Time_of_service'] = df_train['Time_of_service'].replace(np.NaN, df_train['Time_of_service'].mean())
df_train['Work_Life_balance'] = df_train['Work_Life_balance'].replace(np.NaN, df_train['Work_Life_balance'].mean())
df_train['Pay_Scale'] = df_train['Pay_Scale'].replace(np.NaN, df_train['Pay_Scale'].mean())

df_train.isnull().sum()
# Out:
# Employee_ID                  0
# Gender                       0
# Age                          0
# Education_Level              0
# Relationship_Status          0
# Hometown                     0
# Unit                         0
# Decision_skill_possess       0
# Time_of_service              0
# Time_since_promotion         0
# growth_rate                  0
# Travel_Rate                  0
# Post_Level                   0
# Pay_Scale                    0
# Compensation_and_Benefits    0
# Work_Life_balance            0
# VAR1                         0
# VAR2                         0
# VAR3                         0
# VAR4                         0
# VAR5                         0
# VAR6                         0
# VAR7                         0
# Attrition_rate               0
# dtype: int64

# %%
df_test['VAR2'] = df_test['VAR2'].replace(np.NaN, df_test['VAR2'].mean())
df_test['VAR4'] = df_test['VAR4'].replace(np.NaN, df_test['VAR4'].mean())
df_test['Age'] = df_test['Age'].replace(np.NaN, df_test['Age'].mean())
df_test['Time_of_service'] = df_test['Time_of_service'].replace(np.NaN, df_test['Time_of_service'].mean())
df_test['Work_Life_balance'] = df_test['Work_Life_balance'].replace(np.NaN, df_test['Work_Life_balance'].mean())
df_test['Pay_Scale'] = df_test['Pay_Scale'].replace(np.NaN, df_test['Pay_Scale'].mean())


df_test.isnull().sum()
# Out:
# Employee_ID                  0
# Gender                       0
# Age                          0
# Education_Level              0
# Relationship_Status          0
# Hometown                     0
# Unit                         0
# Decision_skill_possess       0
# Time_of_service              0
# Time_since_promotion         0
# growth_rate                  0
# Travel_Rate                  0
# Post_Level                   0
# Pay_Scale                    0
# Compensation_and_Benefits    0
# Work_Life_balance            0
# VAR1                         0
# VAR2                         0
# VAR3                         0
# VAR4                         0
# VAR5                         0
# VAR6                         0
# VAR7                         0
# dtype: int64

# %%
df_train.corr(method ='spearman')
# Out:
#                            Age  Education_Level  Time_of_service  \
# Age                   1.000000        -0.003882         0.897717
# Education_Level      -0.003882         1.000000        -0.009382
# Time_of_service       0.897717        -0.009382         1.000000
# Time_since_promotion  0.142692        -0.005060         0.173455
# growth_rate           0.000675         0.001425        -0.005601
# Travel_Rate           0.011425        -0.014875         0.001108
# Post_Level            0.003643         0.004146        -0.002984
# Pay_Scale             0.010636         0.010978         0.016732
# Work_Life_balance     0.002169        -0.017202        -0.002522
# VAR1                  0.000212        -0.004972        -0.001862
# VAR2                  0.003296        -0.006457         0.002778
# VAR3                  0.006460        -0.010354         0.005769
# VAR4                  0.010608         0.003214         0.000031
# VAR5                 -0.000737         0.005538         0.002740
# VAR6                 -0.000706         0.006463         0.007574
# VAR7                  0.009386         0.011323         0.009058
# Attrition_rate       -0.013677         0.001256        -0.015533
#
#                       Time_since_promotion  growth_rate  Travel_Rate  \
# Age                               0.142692     0.000675     0.011425
# Education_Level                  -0.005060     0.001425    -0.014875
# Time_of_service                   0.173455    -0.005601     0.001108
# Time_since_promotion              1.000000     0.015015    -0.010615
# growth_rate                       0.015015     1.000000     0.008886
# Travel_Rate                      -0.010615     0.008886     1.000000
# Post_Level                       -0.008001    -0.007743     0.021446
# Pay_Scale                        -0.007598    -0.002222    -0.010445
# Work_Life_balance                -0.006033    -0.019141     0.003536
# VAR1                             -0.004463     0.010456     0.024097
# VAR2                              0.004039     0.012423     0.006107
# VAR3                             -0.004485     0.013425    -0.005101
# VAR4                             -0.004570     0.020663    -0.005884
# VAR5                              0.001923    -0.016532    -0.002165
# VAR6                              0.019638    -0.004628    -0.008539
# VAR7                              0.003930    -0.016190    -0.005703
# Attrition_rate                    0.011419     0.009352    -0.014317
#
#                       Post_Level  Pay_Scale  Work_Life_balance      VAR1  \
# Age                     0.003643   0.010636           0.002169  0.000212
# Education_Level         0.004146   0.010978          -0.017202 -0.004972
# Time_of_service        -0.002984   0.016732          -0.002522 -0.001862
# Time_since_promotion   -0.008001  -0.007598          -0.006033 -0.004463
# growth_rate            -0.007743  -0.002222          -0.019141  0.010456
# Travel_Rate             0.021446  -0.010445           0.003536  0.024097
# Post_Level              1.000000   0.017364          -0.014618 -0.010102
# Pay_Scale               0.017364   1.000000          -0.022693  0.010281
# Work_Life_balance      -0.014618  -0.022693           1.000000 -0.028751
# VAR1                   -0.010102   0.010281          -0.028751  1.000000
# VAR2                   -0.006912   0.009992           0.001703 -0.001824
# VAR3                    0.008281   0.005010           0.002580  0.000091
# VAR4                   -0.012867   0.000312          -0.022103  0.003048
# VAR5                    0.010108   0.012990           0.023234  0.000330
# VAR6                    0.004930  -0.013075           0.004955 -0.006931
# VAR7                   -0.000938   0.004057           0.024004  0.008630
# Attrition_rate          0.024648  -0.005622           0.010660 -0.020526
#
#                           VAR2      VAR3      VAR4      VAR5      VAR6  \
# Age                   0.003296  0.006460  0.010608 -0.000737 -0.000706
# Education_Level      -0.006457 -0.010354  0.003214  0.005538  0.006463
# Time_of_service       0.002778  0.005769  0.000031  0.002740  0.007574
# Time_since_promotion  0.004039 -0.004485 -0.004570  0.001923  0.019638
# growth_rate           0.012423  0.013425  0.020663 -0.016532 -0.004628
# Travel_Rate           0.006107 -0.005101 -0.005884 -0.002165 -0.008539
# Post_Level           -0.006912  0.008281 -0.012867  0.010108  0.004930
# Pay_Scale             0.009992  0.005010  0.000312  0.012990 -0.013075
# Work_Life_balance     0.001703  0.002580 -0.022103  0.023234  0.004955
# VAR1                 -0.001824  0.000091  0.003048  0.000330 -0.006931
# VAR2                  1.000000  0.014390  0.003087 -0.001398  0.003386
# VAR3                  0.014390  1.000000  0.000063 -0.002491  0.005114
# VAR4                  0.003087  0.000063  1.000000  0.002152  0.012768
# VAR5                 -0.001398 -0.002491  0.002152  1.000000 -0.005370
# VAR6                  0.003386  0.005114  0.012768 -0.005370  1.000000
# VAR7                  0.003294  0.005600 -0.021691  0.002305  0.015021
# Attrition_rate       -0.022610  0.006374 -0.003183 -0.000693  0.007294
#
#                           VAR7  Attrition_rate
# Age                   0.009386       -0.013677
# Education_Level       0.011323        0.001256
# Time_of_service       0.009058       -0.015533
# Time_since_promotion  0.003930        0.011419
# growth_rate          -0.016190        0.009352
# Travel_Rate          -0.005703       -0.014317
# Post_Level           -0.000938        0.024648
# Pay_Scale             0.004057       -0.005622
# Work_Life_balance     0.024004        0.010660
# VAR1                  0.008630       -0.020526
# VAR2                  0.003294       -0.022610
# VAR3                  0.005600        0.006374
# VAR4                 -0.021691       -0.003183
# VAR5                  0.002305       -0.000693
# VAR6                  0.015021        0.007294
# VAR7                  1.000000       -0.008706
# Attrition_rate       -0.008706        1.000000

# %% [markdown]
# Preparing data & ml model

# %%
df_train.Compensation_and_Benefits = df_train.Compensation_and_Benefits.str[-1:]
df_train.Compensation_and_Benefits = df_train.Compensation_and_Benefits.astype(int)
df_train.Compensation_and_Benefits += 1

# %%
df_test.Compensation_and_Benefits = df_test.Compensation_and_Benefits.str[-1:]
df_test.Compensation_and_Benefits = df_test.Compensation_and_Benefits.astype(int)
df_test.Compensation_and_Benefits += 1

# %%
df_train.head()
# Out:
#   Employee_ID Gender   Age  Education_Level Relationship_Status     Hometown  \
# 0   EID_23371      F  42.0                4             Married     Franklin
# 1   EID_18000      M  24.0                3              Single  Springfield
# 2    EID_3891      F  58.0                3             Married      Clinton
# 3   EID_17492      F  26.0                3              Single      Lebanon
# 4   EID_22534      F  31.0                1             Married  Springfield
#
#                         Unit Decision_skill_possess  Time_of_service  \
# 0                         IT             Conceptual              4.0
# 1                  Logistics             Analytical              5.0
# 2                    Quality             Conceptual             27.0
# 3  Human Resource Management             Behavioral              4.0
# 4                  Logistics             Conceptual              5.0
#
#    Time_since_promotion  growth_rate  Travel_Rate  Post_Level  Pay_Scale  \
# 0                     4           33            1           1        7.0
# 1                     4           36            0           3        6.0
# 2                     3           51            0           2        8.0
# 3                     3           56            1           3        8.0
# 4                     4           62            1           3        2.0
#
#    Compensation_and_Benefits  Work_Life_balance  VAR1    VAR2    VAR3  \
# 0                          3                3.0     4  0.7516  1.8688
# 1                          3                4.0     3 -0.9612 -0.4537
# 2                          3                1.0     4 -0.9612 -0.4537
# 3                          3                1.0     3 -1.8176 -0.4537
# 4                          4                3.0     1  0.7516 -0.4537
#
#        VAR4  VAR5  VAR6  VAR7  Attrition_rate
# 0  2.000000     4     5     3          0.1841
# 1  2.000000     3     5     3          0.0670
# 2  3.000000     3     8     3          0.0851
# 3  1.891078     3     7     3          0.0668
# 4  2.000000     2     8     2          0.1827

# %%
df_test.dtypes
# Out:
# Employee_ID                   object
# Gender                        object
# Age                          float64
# Education_Level                int64
# Relationship_Status           object
# Hometown                      object
# Unit                          object
# Decision_skill_possess        object
# Time_of_service              float64
# Time_since_promotion           int64
# growth_rate                    int64
# Travel_Rate                    int64
# Post_Level                     int64
# Pay_Scale                    float64
# Compensation_and_Benefits      int32
# Work_Life_balance            float64
# VAR1                           int64
# VAR2                         float64
# VAR3                         float64
# VAR4                         float64
# VAR5                           int64
# VAR6                           int64
# VAR7                           int64
# dtype: object

# %%
x_train = df_train.drop(['Employee_ID', 'Gender', 'Relationship_Status', 'Hometown', 'Unit',
                        'Decision_skill_possess', 'Attrition_rate'], axis = 1).to_numpy()
print('X Trian shape:',x_train.shape)

x_test = df_test.drop(['Employee_ID', 'Gender', 'Relationship_Status', 'Hometown', 'Unit',
                        'Decision_skill_possess'], axis = 1).to_numpy()

print('X Test shape:',x_test.shape)

y_train = df_train.Attrition_rate
print('Y Trian shape:',y_train.shape)
# Out:
# X Trian shape: (7000, 17)
# X Test shape: (3000, 17)
# Y Trian shape: (7000,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

model = LinearRegression()

model.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# coefficeints of the trained model
print('\nCoefficient of model :', model.coef_)

# intercept of the model
print('\nIntercept of model',model.intercept_)
# Out:
# Coefficient of model : [-7.75825979e-05 -1.40587935e-03 -2.41511872e-04  2.69279635e-03
#   1.70684067e-04 -3.83832768e-03  2.79601765e-03 -1.27489681e-03
#  -6.29739968e-03  3.38415724e-03 -1.61078435e-03 -4.34211166e-03
#   1.27311841e-04 -4.44587169e-03 -9.72879539e-04 -4.88170784e-04
#  -3.06987197e-03]
#
# Intercept of model 0.23145124617000148

# %%
y_pred = model.predict(x_train)
mean_squared_error(y_train, y_pred)
# Out:
# 0.03437840887824524

# %% [markdown]
# Score of 81.27837 achieved

# %%
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error

model = SVR(kernel = 'rbf')

model.fit(x_train, y_train)
# Out:
# C:\Users\Utkarsh\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#     gamma='auto_deprecated', kernel='rbf', max_iter=-1, shrinking=True,
#     tol=0.001, verbose=False)

# %%
y_pred = model.predict(x_train)
mean_squared_error(y_train, y_pred)
# Out:
# 0.007304152095913592

# %%
# Training the Decision Tree Regression model on the whole dataset
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor(random_state = 0)
model.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-224-6ce267a7c2ca> in <module>
#       1 # Training the Decision Tree Regression model on the whole dataset
# ----> 2 from sklearn.tree import DecisionTreeRegressor
#       3 model = DecisionTreeRegressor(random_state = 0)
#       4 model.fit(x_train, y_train)
#
# ~\Anaconda3\lib\site-packages\sklearn\tree\__init__.py in <module>
#       4 """
#       5
# ----> 6 from ._classes import BaseDecisionTree
#       7 from ._classes import DecisionTreeClassifier
#       8 from ._classes import DecisionTreeRegressor
#
# ~\Anaconda3\lib\site-packages\sklearn\tree\_classes.py in <module>
#      33 from ..utils import check_array
#      34 from ..utils import check_random_state
# ---> 35 from ..utils.validation import _check_sample_weight
#      36 from ..utils import compute_sample_weight
#      37 from ..utils.multiclass import check_classification_targets
#
# ImportError: cannot import name '_check_sample_weight' from 'sklearn.utils.validation' (C:\Users\Utkarsh\Anaconda3\lib\site-packages\sklearn\utils\validation.py)

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 0.21.1

# %%
y_test = model.predict(x_test)
#values, counts = np.unique(y_test, return_counts=True)
#print(values, counts)

# %%
df_submit = pd.DataFrame(df_test['Employee_ID'], columns= submit.columns)
df_submit['Attrition_rate'] = y_test.tolist()
df_submit.to_csv('output.csv', index=False)
df_submit.head()
# Out:
#   Employee_ID  Attrition_rate
# 0   EID_22713        0.418238
# 1    EID_9658        0.245259
# 2   EID_22203        0.212062
# 3    EID_7652        0.241535
# 4    EID_6516        0.180228
